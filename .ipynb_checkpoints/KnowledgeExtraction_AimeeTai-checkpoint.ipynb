# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import piecewise_regression
import pywt
from scipy.signal import savgol_filter, find_peaks

import warnings
warnings.filterwarnings("ignore")

#Functions
def namestr(obj, namespace):
    return [name for name in namespace if namespace[name] is obj][0]

def thresholding(coeffs, threshold):
    return [pywt.threshold(c, threshold, mode='soft') for c in coeffs]

def getStressStrainCurve(data_list, thickness_info = True, thickness_list = None, cut_off_load = 2):
    # convert in to um
    for i in range(len(data_list)):
        data_list[i]['S:LVDT (um)'] = data_list[i]['S:LVDT (in)'] * 25.4 * 1000
        # create stress column which is load / area, the area is 19.635 mm^2
        data_list[i]['stress (bar)'] = data_list[i]['Ch:Load (N)'] / 19.635 *10

    if thickness_info:
        thickness = thickness_list
        x_axis = 'strain'
        x_axis_label = 'Strain'
        # convert in to um
        for i in range(len(data_list)): 
            # create strain column which is displacement / thickness, the thickness is shown above
            data_list[i]['strain'] = data_list[i]['S:LVDT (um)'] / thickness[i]
    else:
        x_axis = 'S:LVDT (um)'
        x_axis_label = 'Displacement (um)'
    data_list_cleaned = []

    # Plot these in the same graph to compare them
    plt.figure(figsize=(8, 6))
    for i in range(len(data_list)):
        data_name = namestr(data_list[i], globals())
        data = data_list[i][data_list[i]['Ch:Load (N)'] > cut_off_load]
        data = data.loc[:data['Ch:Load (N)'].idxmax()]
        # shift the data so that the first point is at 0 in 'S:LVDT (in)'
        data[x_axis] = data[x_axis] - data[x_axis].iloc[0]
        data_list_cleaned.append(data)
        plt.plot(data[x_axis], data['stress (bar)'], label=data_name)
    plt.xlabel(x_axis_label)
    plt.ylabel('Stress (bar)')
    plt.legend(loc='upper left')
    plt.show()

def denoiseData_SavitskyGolay(data_list, cut_off_load = 2): #need to add to the dataframe to use the denoised data
    for i in range(len(data_list)):
        # Apply Savitzky-Golay filter
        window_length = 400  # Length of the filter window (must be a positive odd integer)
        polyorder = 3       # Order of the polynomial used to fit the samples (must be less than window_length)

        # Align strain to 0
        data = data_list[i][data_list[i]['Ch:Load (N)'] > cut_off_load]
        data = data.loc[:data['Ch:Load (N)'].idxmax()]
        # Shift the data so that the first point is at 0 in 'S:LVDT (in)'
        data['strain'] = data['strain'] - data['strain'].iloc[0]
        data["stress (bar)"] = data["stress (bar)"] - data['strain'].iloc[0]

        data["denoised stress (bar)"] = savgol_filter(data["stress (bar)"], window_length, polyorder)
        data["denoised stress (bar)"] = data["denoised stress (bar)"].rolling(window=120).mean()
        data_list[i]["denoised stress(bar)"] = data["denoised stress (bar)"]
        data_list[i]["denoised strain"] = data['strain']
        
        # Plotting the results
        plt.figure(figsize=(10, 6))
        plt.plot(data['strain'], data["stress (bar)"], label='Noisy data')
        plt.plot(data['strain'], data["denoised stress (bar)"], label='Smoothed data', color='red')
        plt.legend()
        plt.xlabel('strain')
        plt.ylabel('stress (bar)')
        plt.title('Savitzky-Golay Filter Smoothing')
        plt.show()

def validDataCheck_Correlation(data_list):
    df = pd.DataFrame()
    for i in range(len(data_list)):
        data_name = namestr(data_list[i], globals())
        df[data_name] = data_list[i]["stress (bar)"]
    pearson_corr = df.corr(method='pearson')

    print(pearson_corr)
    pearson_corr = pearson_corr.values.flatten().tolist()
    
    x = True
    for i in range(len(pearson_corr)):
        if math.ceil(pearson_corr[i]) < 0.95:
                x = False
    return x

def segmentingTheCurve_PiecewiseRegression(data_list, cut_off_load = 2):
    for i in range(len(data_list)):
    
        #ms = piecewise_regression.ModelSelection(list(data_list[0]['strain']), list(data_list[0]['stress (bar)']), max_breakpoints=15)
        #print(ms.isoformat())

        data = data_list[i][data_list[i]['Ch:Load (N)'] > cut_off_load]
        data = data.loc[:data['Ch:Load (N)'].idxmax()]
        # shift the data so that the first point is at 0 in 'S:LVDT (in)'
        data['strain'] = data['strain'] - data['strain'].iloc[0]
        data["stress (bar)"] = data["stress (bar)"] - data['strain'].iloc[0]

        print(data_list[i])
        
        pw_fit = piecewise_regression.Fit(list(data_list[i]['denoised strain']), list(data_list[i]['denoised stress(bar)']), n_breakpoints=5)
        pw_fit.plot_fit(color="red", linewidth=2)
        pw_fit.plot_data(color="grey", s=1)
        pw_fit.plot_breakpoints()
        pw_fit.plot_breakpoint_confidence_intervals()
        plt.title("Piecewise Regression")
        plt.xlabel("Strain")
        plt.ylabel("Stress (bar)")
        plt.show()
        pw_fit.summary()

# %%
# Good Data
Auto_noheating_17wt_3_1 = pd.read_csv('Data/Compression Sample NH 10, 12, 15, 17 batch 3/AutoNoheating-17-3-1-240212_02122024_180801.csv')
Auto_noheating_17wt_3_2 = pd.read_csv('Data/Compression Sample NH 10, 12, 15, 17 batch 3/AutoNoheating-17-3-2-240212_02122024_181028.csv')
Auto_noheating_17wt_3_3 = pd.read_csv('Data/Compression Sample NH 10, 12, 15, 17 batch 3/AutoNoheating-17-3-3-240212_02122024_181307.csv')
Auto_noheating_17wt_3_4 = pd.read_csv('Data/Compression Sample NH 10, 12, 15, 17 batch 3/AutoNoheating-17-3-4-240212_02122024_181657.csv')

data_list_17_3 = [Auto_noheating_17wt_3_1, Auto_noheating_17wt_3_2, Auto_noheating_17wt_3_3, Auto_noheating_17wt_3_4]
thickness_17_3 = [110,105,105,105]

getStressStrainCurve(data_list_17_3, thickness_info = True, thickness_list = thickness_17_3)
denoiseData_SavitskyGolay(data_list_17_3)
segmentingTheCurve_PiecewiseRegression(data_list_17_3)
# Out:
#       Time (sec)  S:Load (lbs)  S:HL1 (DIM)  S:LVDT (in)  S:Position (in)  \
# 0       0.110000      0.008186  -307.096497     0.000000        -0.000000
# 1       0.120000      0.009682  -307.052002     0.000034        -0.000000
# 2       0.130000      0.005211  -307.096497     0.000009        -0.000000
# 3       0.140000      0.004837  -307.096497    -0.000004        -0.000000
# 4       0.150000     -0.003731  -307.096497    -0.000004        -0.000000
# ...          ...           ...          ...          ...              ...
# 8695   87.060005     53.947830  -309.053650     0.005083         0.003397
# 8696   87.070007     53.941498  -309.098114     0.005109         0.003397
# 8697   87.080002     53.940758  -309.053650     0.005105         0.003397
# 8698   87.090004     53.940758  -309.053650     0.005109         0.003397
# 8699   87.100006     53.931076  -309.053650     0.005144         0.003397
#
#       Ch:Position (mm)  Ch:Load (N)  Ch:Stress (MPa)  Ch:Strain (mm/mm)  \
# 0            -0.000000     0.036415         0.001855          -0.000000
# 1            -0.000000     0.043066         0.002194          -0.000000
# 2            -0.000000     0.023179         0.001181          -0.000000
# 3            -0.000000     0.021516         0.001096          -0.000000
# 4            -0.000000    -0.016595        -0.000845          -0.000000
# ...                ...          ...              ...                ...
# 8695          0.086289   239.971939        12.224753           0.862888
# 8696          0.086289   239.943771        12.223318           0.862888
# 8697          0.086289   239.940475        12.223150           0.862888
# 8698          0.086289   239.940475        12.223150           0.862888
# 8699          0.086289   239.897415        12.220957           0.862888
#
#       Ch:HL1 (DIM)  Set Point ()  Cycles ()  S:LVDT (um)  stress (bar)  \
# 0      -307.096497      0.000191        0.0       0.0000      0.018546
# 1      -307.052002      0.000191        0.0       0.8636      0.021933
# 2      -307.096497      0.000191        0.0       0.2286      0.011805
# 3      -307.096497      0.000191        0.0      -0.1016      0.010958
# 4      -307.096497      0.000191        0.0      -0.1016     -0.008452
# ...            ...           ...        ...          ...           ...
# 8695   -309.053650      0.086471        0.0     129.1082    122.216419
# 8696   -309.098114      0.086471        0.0     129.7686    122.202073
# 8697   -309.053650      0.086471        0.0     129.6670    122.200395
# 8698   -309.053650      0.086471        0.0     129.7686    122.200395
# 8699   -309.053650      0.086471        0.0     130.6576    122.178464
#
#         strain  denoised stress(bar)  denoised strain
# 0     0.000000                   NaN              NaN
# 1     0.007851                   NaN              NaN
# 2     0.002078                   NaN              NaN
# 3    -0.000924                   NaN              NaN
# 4    -0.000924                   NaN              NaN
# ...        ...                   ...              ...
# 8695  1.173711                   NaN              NaN
# 8696  1.179715                   NaN              NaN
# 8697  1.178791                   NaN              NaN
# 8698  1.179715                   NaN              NaN
# 8699  1.187796                   NaN              NaN
#
# [8700 rows x 17 columns]
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[14], line 12
#      10 getStressStrainCurve(data_list_17_3, thickness_info = True, thickness_list = thickness_17_3)
#      11 denoiseData_SavitskyGolay(data_list_17_3)
# ---> 12 segmentingTheCurve_PiecewiseRegression(data_list_17_3)
#
# Cell In[13], line 112, in segmentingTheCurve_PiecewiseRegression(data_list, cut_off_load)
#     108 data["stress (bar)"] = data["stress (bar)"] - data['strain'].iloc[0]
#     110 print(data_list[i])
# --> 112 pw_fit = piecewise_regression.Fit(list(data_list[i]['denoised strain']), list(data_list[i]['denoised stress(bar)']), n_breakpoints=5)
#     113 pw_fit.plot_fit(color="red", linewidth=2)
#     114 pw_fit.plot_data(color="grey", s=1)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\piecewise_regression\main.py:712, in Fit.__init__(self, xx, yy, start_values, n_breakpoints, n_boot, verbose, max_iterations, tolerance, min_distance_between_breakpoints, min_distance_to_edge)
#     709 self.best_muggeo = None
#     710 self.stop = False
# --> 712 self.bootstrap_restarting()
#     714 self.davies = davies.davies_test(self.xx, self.yy)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\piecewise_regression\main.py:767, in Fit.bootstrap_restarting(self)
#     751 """
#     752 The main fitting algorithm. Begins by doing a fit based on
#     753 Muggeo's algorithm.
#    (...)
#     764     fit that converged - defined as the lowest residual sum of squares.
#     765 """
#     766 min_d_between_bps = self.min_distance_between_breakpoints
# --> 767 muggeo_fit = Muggeo(
#     768     xx=self.xx,
#     769     yy=self.yy,
#     770     start_values=self.start_values,
#     771     n_breakpoints=self.n_breakpoints,
#     772     max_iterations=self.max_iterations,
#     773     tolerance=self.tolerance,
#     774     verbose=self.verbose,
#     775     min_distance_between_breakpoints=min_d_between_bps,
#     776     min_distance_to_edge=self.min_distance_to_edge)
#     778 self.bootstrap_history.append(muggeo_fit)
#     780 # best_muggeo is the best converged muggeo
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\piecewise_regression\main.py:415, in Muggeo.__init__(self, xx, yy, n_breakpoints, start_values, verbose, max_iterations, tolerance, min_distance_between_breakpoints, min_distance_to_edge)
#     412 self.min_distance_to_edge = min_distance_to_edge
#     414 if start_values is None:
# --> 415     start_values = self._generate_breakpoints()
#     417 self.start_values = self._validate_start_values(start_values)
#     419 self.max_iterations = max_iterations
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\piecewise_regression\main.py:586, in Muggeo._generate_breakpoints(self)
#     584 min_allowed_bp = np.quantile(self.xx, self.min_distance_to_edge)
#     585 max_allowed_bp = np.quantile(self.xx, 1 - self.min_distance_to_edge)
# --> 586 start_values = np.random.uniform(
#     587     low=min_allowed_bp, high=max_allowed_bp, size=self.n_breakpoints)
#     588 if self.verbose:
#     589     print("Generating some random breakpoints: ", start_values)
#
# File numpy\\random\\mtrand.pyx:1156, in numpy.random.mtrand.RandomState.uniform()
#
# OverflowError: Range exceeds valid bounds
