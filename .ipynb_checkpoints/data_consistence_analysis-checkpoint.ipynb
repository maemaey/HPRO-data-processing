# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import piecewise_regression
import re
def namestr(obj, namespace):
    return [name for name in namespace if namespace[name] is obj][0]
# ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
Auto_noheating_10wt_1 = pd.read_csv('Data/Automembrane/AutoNoheat10-1-1_12132023_184312.csv')
Auto_noheating_10wt_2 = pd.read_csv('Data/Automembrane/AutoNoheat10-1-2_12132023_184624.csv')
Auto_noheating_10wt_3 = pd.read_csv('Data/Automembrane/AutoNoheat10-1-3_12132023_184911.csv')
Auto_noheating_10wt_4 = pd.read_csv('Data/Automembrane/AutoNoheat10-1-4_12132023_185155.csv')
data_list_10_1 = [Auto_noheating_10wt_1, Auto_noheating_10wt_2, Auto_noheating_10wt_3, Auto_noheating_10wt_4]

Auto_noheating_12wt_1_1_1 = pd.read_csv('Data/Automembrane/AutoNoheat12-1-1_12132023_180629.csv')
Auto_noheating_12wt_1_1_2 = pd.read_csv('Data/Automembrane/AutoNoheat12-1-2_12132023_180947.csv')
Auto_noheating_12wt_1_1_3 = pd.read_csv('Data/Automembrane/AutoNoheat12-1-3_12132023_181314.csv')
Auto_noheating_12wt_1_1_4 = pd.read_csv('Data/Automembrane/AutoNoheat12-1-4_12132023_181753.csv')

data_list_12_1_1 = [Auto_noheating_12wt_1_1_1, Auto_noheating_12wt_1_1_2, Auto_noheating_12wt_1_1_3, Auto_noheating_12wt_1_1_4]

Auto_noheating_12wt_1_2_1 = pd.read_csv('Data/Automembrane/AutoNoheat12-2-1_12132023_182727.csv')
Auto_noheating_12wt_1_2_2 = pd.read_csv('Data/Automembrane/AutoNoheat12-2-2_12132023_183111.csv')
Auto_noheating_12wt_1_2_3 = pd.read_csv('Data/Automembrane/AutoNoheat12-2-3_12132023_183350.csv')
Auto_noheating_12wt_1_2_4 = pd.read_csv('Data/Automembrane/AutoNoheat12-2-4_12132023_183653.csv')

data_list_12_1_2 = [Auto_noheating_12wt_1_2_1, Auto_noheating_12wt_1_2_2, Auto_noheating_12wt_1_2_3, Auto_noheating_12wt_1_2_4]

Auto_noheating_15wt_1 = pd.read_csv('Data/Automembrane/AutoNoheat15-1-1_12132023_185751.csv')
Auto_noheating_15wt_2 = pd.read_csv('Data/Automembrane/AutoNoheat15-1-2_12132023_190025.csv')
Auto_noheating_15wt_3 = pd.read_csv('Data/Automembrane/AutoNoheat15-1-3_12132023_190242.csv')
Auto_noheating_15wt_4 = pd.read_csv('Data/Automembrane/AutoNoheat15-1-4_12132023_190508.csv')

data_list_15_1 = [Auto_noheating_15wt_1, Auto_noheating_15wt_2, Auto_noheating_15wt_3, Auto_noheating_15wt_4]

Auto_heating_10wt_1 = pd.read_csv('Data/Automembrane/AutoHeating-10wt-1-1_12152023_180149.csv')
Auto_heating_10wt_2 = pd.read_csv('Data/Automembrane/AutoHeating-10wt-1-2_12152023_180445.csv')
Auto_heating_10wt_3 = pd.read_csv('Data/Automembrane/AutoHeating-10wt-1-3_12152023_180733.csv')
Auto_heating_10wt_4 = pd.read_csv('Data/Automembrane/AutoHeating-10wt-1-4_12152023_181010.csv')

data_list_10_1_H = [Auto_heating_10wt_1, Auto_heating_10wt_2, Auto_heating_10wt_3, Auto_heating_10wt_4]

Auto_heating_12wt_1 = pd.read_csv('Data/Automembrane/AutoHeating-12wt-1-1_12152023_174451.csv')
Auto_heating_12wt_2 = pd.read_csv('Data/Automembrane/AutoHeating-12wt-1-2_12152023_174720.csv')
Auto_heating_12wt_3 = pd.read_csv('Data/Automembrane/AutoHeating-12wt-1-3_12152023_175002.csv')
Auto_heating_12wt_4 = pd.read_csv('Data/Automembrane/AutoHeating-12wt-1-4_12152023_175315.csv')

data_list_12_1_H = [Auto_heating_12wt_1, Auto_heating_12wt_2, Auto_heating_12wt_3, Auto_heating_12wt_4]

Auto_heating_15wt_1 = pd.read_csv('Data/Automembrane/AutoHeating-15wt-1-1_12152023_164942.csv')
Auto_heating_15wt_2 = pd.read_csv('Data/Automembrane/AutoHeating-15wt-1-2_12152023_165240.csv')
Auto_heating_15wt_3 = pd.read_csv('Data/Automembrane/AutoHeating-15wt-1-3_12152023_165505.csv')
Auto_heating_15wt_4 = pd.read_csv('Data/Automembrane/AutoHeating-15wt-1-4_12152023_165728.csv')

data_list_15_1_H = [Auto_heating_15wt_1, Auto_heating_15wt_2, Auto_heating_15wt_3, Auto_heating_15wt_4]

Auto_heating_17wt_1 = pd.read_csv('Data/Automembrane/AutoHeating-17wt-1-1_12152023_163238.csv')
Auto_heating_17wt_2 = pd.read_csv('Data/Automembrane/AutoHeating-17wt-1-2_12152023_163546.csv')
Auto_heating_17wt_3 = pd.read_csv('Data/Automembrane/AutoHeating-17wt-1-3_12152023_163810.csv')
Auto_heating_17wt_4 = pd.read_csv('Data/Automembrane/AutoHeating-17wt-1-4_12152023_164019.csv')

data_list_17_1_H = [Auto_heating_17wt_1, Auto_heating_17wt_2, Auto_heating_17wt_3, Auto_heating_17wt_4]

Auto_noheating_10wt_2_1 = pd.read_csv('Data/compression sample NH 10,12,15/AutoNoheating-10-2-1-240201_02012024_190744.csv')
Auto_noheating_10wt_2_2 = pd.read_csv('Data/compression sample NH 10,12,15/AutoNoheating-10-2-2-240201_02012024_191026.csv')
Auto_noheating_10wt_2_3 = pd.read_csv('Data/compression sample NH 10,12,15/AutoNoheating-10-2-3-240201_02012024_191401.csv')
Auto_noheating_10wt_2_4 = pd.read_csv('Data/compression sample NH 10,12,15/AutoNoheating-10-2-4-240201_02012024_191648.csv')

data_list_10_2 = [Auto_noheating_10wt_2_1, Auto_noheating_10wt_2_2, Auto_noheating_10wt_2_3, Auto_noheating_10wt_2_4]

Auto_noheating_12wt_2_1 = pd.read_csv('Data/compression sample NH 10,12,15/AutoNoheating-12-2-1-240201_02012024_183453.csv')
Auto_noheating_12wt_2_2 = pd.read_csv('Data/compression sample NH 10,12,15/AutoNoheating-12-2-2-240201_02012024_183730.csv')
Auto_noheating_12wt_2_3 = pd.read_csv('Data/compression sample NH 10,12,15/AutoNoheating-12-2-3-240201_02012024_184035.csv')
Auto_noheating_12wt_2_4 = pd.read_csv('Data/compression sample NH 10,12,15/AutoNoheating-12-2-4-240201_02012024_184313.csv')

data_list_12_2 = [Auto_noheating_12wt_2_1, Auto_noheating_12wt_2_2, Auto_noheating_12wt_2_3, Auto_noheating_12wt_2_4]

Auto_noheating_15wt_2_1 = pd.read_csv('Data/compression sample NH 10,12,15/AutoNoheating-15-2-1-240201_02012024_181434.csv')
Auto_noheating_15wt_2_2 = pd.read_csv('Data/compression sample NH 10,12,15/AutoNoheating-15-2-2-240201_02012024_181804.csv')
Auto_noheating_15wt_2_3 = pd.read_csv('Data/compression sample NH 10,12,15/AutoNoheating-15-2-3-240201_02012024_182043.csv')
Auto_noheating_15wt_2_4 = pd.read_csv('Data/compression sample NH 10,12,15/AutoNoheating-15-2-4-240201_02012024_182359.csv')

data_list_15_2 = [Auto_noheating_15wt_2_1, Auto_noheating_15wt_2_2, Auto_noheating_15wt_2_3, Auto_noheating_15wt_2_4]
    
Auto_noheating_10wt_3_1 = pd.read_csv('Data/Compression Sample NH 10, 12, 15, 17 batch 3/AutoNoheating-10-3-1-240212_02122024_160514.csv')
Auto_noheating_10wt_3_2 = pd.read_csv('Data/Compression Sample NH 10, 12, 15, 17 batch 3/AutoNoheating-10-3-2-240212_02122024_160815.csv')
Auto_noheating_10wt_3_3 = pd.read_csv('Data/Compression Sample NH 10, 12, 15, 17 batch 3/AutoNoheating-10-3-3-240212_02122024_161038.csv')
Auto_noheating_10wt_3_4 = pd.read_csv('Data/Compression Sample NH 10, 12, 15, 17 batch 3/AutoNoheating-10-3-4-240212_02122024_161307.csv')

data_list_10_3 = [Auto_noheating_10wt_3_1, Auto_noheating_10wt_3_2, Auto_noheating_10wt_3_3, Auto_noheating_10wt_3_4]
thickness_10_3 = [109,113,107,106]

Auto_noheating_12wt_3_1 = pd.read_csv('Data/Compression Sample NH 10, 12, 15, 17 batch 3/AutoNoheating-12-3-1-240212_02122024_161808.csv')
Auto_noheating_12wt_3_2 = pd.read_csv('Data/Compression Sample NH 10, 12, 15, 17 batch 3/AutoNoheating-12-3-2-240212_02122024_162105.csv')
Auto_noheating_12wt_3_3 = pd.read_csv('Data/Compression Sample NH 10, 12, 15, 17 batch 3/AutoNoheating-12-3-3-240212_02122024_162358.csv')
Auto_noheating_12wt_3_4 = pd.read_csv('Data/Compression Sample NH 10, 12, 15, 17 batch 3/AutoNoheating-12-3-4-240212_02122024_162658.csv')

data_list_12_3 = [Auto_noheating_12wt_3_1, Auto_noheating_12wt_3_2, Auto_noheating_12wt_3_3, Auto_noheating_12wt_3_4]
thickness_12_3 = [107,110,112,112]

Auto_noheating_15wt_3_1 = pd.read_csv('Data/Compression Sample NH 10, 12, 15, 17 batch 3/AutoNoheating-15-3-1-240212_02122024_175519.csv')
Auto_noheating_15wt_3_2 = pd.read_csv('Data/Compression Sample NH 10, 12, 15, 17 batch 3/AutoNoheating-15-3-2-240212_02122024_175755.csv')
Auto_noheating_15wt_3_3 = pd.read_csv('Data/Compression Sample NH 10, 12, 15, 17 batch 3/AutoNoheating-15-3-3-240212_02122024_180046.csv')
Auto_noheating_15wt_3_4 = pd.read_csv('Data/Compression Sample NH 10, 12, 15, 17 batch 3/AutoNoheating-15-3-4-240212_02122024_180316.csv')

data_list_15_3 = [Auto_noheating_15wt_3_1, Auto_noheating_15wt_3_2, Auto_noheating_15wt_3_3, Auto_noheating_15wt_3_4]
thickness_15_3 = [103,105,105,105]

Auto_noheating_17wt_3_1 = pd.read_csv('Data/Compression Sample NH 10, 12, 15, 17 batch 3/AutoNoheating-17-3-1-240212_02122024_180801.csv')
Auto_noheating_17wt_3_2 = pd.read_csv('Data/Compression Sample NH 10, 12, 15, 17 batch 3/AutoNoheating-17-3-2-240212_02122024_181028.csv')
Auto_noheating_17wt_3_3 = pd.read_csv('Data/Compression Sample NH 10, 12, 15, 17 batch 3/AutoNoheating-17-3-3-240212_02122024_181307.csv')
Auto_noheating_17wt_3_4 = pd.read_csv('Data/Compression Sample NH 10, 12, 15, 17 batch 3/AutoNoheating-17-3-4-240212_02122024_181657.csv')

data_list_17_3 = [Auto_noheating_17wt_3_1, Auto_noheating_17wt_3_2, Auto_noheating_17wt_3_3, Auto_noheating_17wt_3_4]
thickness_17_3 = [110,105,105,105]

Auto_noheating_10wt_4_1 = pd.read_csv('Data/compression 4/AutoNoheating-10-4-1-240223_02232024_161809.csv')
Auto_noheating_10wt_4_2 = pd.read_csv('Data/compression 4/AutoNoheating-10-4-2-240223_02232024_162119.csv')
Auto_noheating_10wt_4_3 = pd.read_csv('Data/compression 4/AutoNoheating-10-4-3-240223_02232024_162456.csv')

data_list_10_4 = [Auto_noheating_10wt_4_1, Auto_noheating_10wt_4_2, Auto_noheating_10wt_4_3]
thickness_10_4 = [105,105,105]

Auto_noheating_12wt_4_1 = pd.read_csv('Data/compression 4/AutoNoheating-12-4-1-240223_02232024_163339.csv')
Auto_noheating_12wt_4_2 = pd.read_csv('Data/compression 4/AutoNoheating-12-4-2-240223_02232024_163631.csv')
Auto_noheating_12wt_4_3 = pd.read_csv('Data/compression 4/AutoNoheating-12-4-3-240223_02232024_163935.csv')
Auto_noheating_12wt_4_4 = pd.read_csv('Data/compression 4/AutoNoheating-12-4-4-240223_02232024_164316.csv')
Auto_noheating_12wt_4_5 = pd.read_csv('Data/compression 4/AutoNoheating-12-4-5-240223_02232024_164618.csv')

data_list_12_4 = [Auto_noheating_12wt_4_1, Auto_noheating_12wt_4_2, Auto_noheating_12wt_4_3, Auto_noheating_12wt_4_4, Auto_noheating_12wt_4_5]
thickness_12_4 = [111,108,104,104,102]

Auto_noheating_15wt_4_1 = pd.read_csv('Data/compression 4 4 days/AutoNoheating-15-4-1-240226_02262024_162514.csv')
Auto_noheating_15wt_4_2 = pd.read_csv('Data/compression 4 4 days/AutoNoheating-15-4-2-240226_02262024_162808.csv')
Auto_noheating_15wt_4_3 = pd.read_csv('Data/compression 4 4 days/AutoNoheating-15-4-3-240226_02262024_163110.csv')
Auto_noheating_15wt_4_4 = pd.read_csv('Data/compression 4 4 days/AutoNoheating-15-4-4-240226_02262024_163353.csv')

data_list_15_4 = [Auto_noheating_15wt_4_1, Auto_noheating_15wt_4_2, Auto_noheating_15wt_4_3, Auto_noheating_15wt_4_4]
thickness_15_4 = [109,103,100,100]

Auto_noheating_17wt_4_1 = pd.read_csv('Data/compression 4 4 days/AutoNoheating-17-4-1-240226_02262024_163853.csv')
Auto_noheating_17wt_4_2 = pd.read_csv('Data/compression 4 4 days/AutoNoheating-17-4-2-240226_02262024_164117.csv')
Auto_noheating_17wt_4_3 = pd.read_csv('Data/compression 4 4 days/AutoNoheating-17-4-3-240226_02262024_164351.csv')
Auto_noheating_17wt_4_4 = pd.read_csv('Data/compression 4 4 days/AutoNoheating-17-4-4-240226_02262024_164621.csv')

data_list_17_4 = [Auto_noheating_17wt_4_1, Auto_noheating_17wt_4_2, Auto_noheating_17wt_4_3, Auto_noheating_17wt_4_4]
thickness_17_4 = [109,106,106,105]

Auto_noheating_10wt_5_1 = pd.read_csv('Data/compression 5/AutoNoheating-10-5-1-240223_02232024_193040.csv')
Auto_noheating_10wt_5_2 = pd.read_csv('Data/compression 5/AutoNoheating-10-5-2-240223_02232024_193342.csv')
Auto_noheating_10wt_5_3 = pd.read_csv('Data/compression 5/AutoNoheating-10-5-3-240223_02232024_193652.csv')
Auto_noheating_10wt_5_4 = pd.read_csv('Data/compression 5/AutoNoheating-10-5-4-240223_02232024_193947.csv')

data_list_10_5 = [Auto_noheating_10wt_5_1, Auto_noheating_10wt_5_2, Auto_noheating_10wt_5_3, Auto_noheating_10wt_5_4]
thickness_10_5 = [117,142,149,118]

Auto_noheating_17wt_5_1 = pd.read_csv('Data/compression 5/AutoNoheating-17-5-1-240223_02232024_194527.csv')
Auto_noheating_17wt_5_2 = pd.read_csv('Data/compression 5/AutoNoheating-17-5-2-240223_02232024_194752.csv')
Auto_noheating_17wt_5_3 = pd.read_csv('Data/compression 5/AutoNoheating-17-5-3-240223_02232024_195016.csv')
Auto_noheating_17wt_5_4 = pd.read_csv('Data/compression 5/AutoNoheating-17-5-4-240223_02232024_195303.csv')

data_list_17_5 = [Auto_noheating_17wt_5_1, Auto_noheating_17wt_5_2, Auto_noheating_17wt_5_3, Auto_noheating_17wt_5_4]
thickness_17_5 = [107,106,101,100]

Auto_noheating_10wt_6_day1_1 = pd.read_csv('Data/compression 6/AutoNoheating-10-6-day1-1-240228_02282024_201331.csv')
Auto_noheating_10wt_6_day1_2 = pd.read_csv('Data/compression 6/AutoNoheating-10-6-day1-2-240228_02282024_201646.csv')
Auto_noheating_10wt_6_day1_3 = pd.read_csv('Data/compression 6/AutoNoheating-10-6-day1-3-240228_02282024_201943.csv')
Auto_noheating_10wt_6_day1_4 = pd.read_csv('Data/compression 6/AutoNoheating-10-6-day1-4-240228_02282024_202246.csv')

data_list_10_6_day1 = [Auto_noheating_10wt_6_day1_1, Auto_noheating_10wt_6_day1_2, Auto_noheating_10wt_6_day1_3, Auto_noheating_10wt_6_day1_4]
thickness_10_6_day1 = [99, 86, 98, 120]

Auto_noheating_10wt_6_day2_1 = pd.read_csv('Data/compression 6/AutoNoheating-10-6-day2-1-240229_02292024_165802.csv')
Auto_noheating_10wt_6_day2_2 = pd.read_csv('Data/compression 6/AutoNoheating-10-6-day2-2-240229_02292024_170133.csv')
Auto_noheating_10wt_6_day2_3 = pd.read_csv('Data/compression 6/AutoNoheating-10-6-day2-3-240229_02292024_170353.csv')
Auto_noheating_10wt_6_day2_4 = pd.read_csv('Data/compression 6/AutoNoheating-10-6-day2-4-240229_02292024_170638.csv')
Auto_noheating_10wt_6_day2_5 = pd.read_csv('Data/compression 6/AutoNoheating-10-6-day2-5-240229_02292024_170950.csv')    

data_list_10_6_day2 = [Auto_noheating_10wt_6_day2_1, Auto_noheating_10wt_6_day2_2, Auto_noheating_10wt_6_day2_3, Auto_noheating_10wt_6_day2_4, Auto_noheating_10wt_6_day2_5]
thickness_10_6_day2 = [76, 76, 62, 130, 156]

Auto_noheating_10wt_6_day3_1 = pd.read_csv('Data/compression 6/AutoNoheating-10-6-day3-1-240301_03012024_155023.csv')
Auto_noheating_10wt_6_day3_2 = pd.read_csv('Data/compression 6/AutoNoheating-10-6-day3-2-240301_03012024_155302.csv')
Auto_noheating_10wt_6_day3_3 = pd.read_csv('Data/compression 6/AutoNoheating-10-6-day3-3-240301_03012024_155535.csv')
Auto_noheating_10wt_6_day3_4 = pd.read_csv('Data/compression 6/AutoNoheating-10-6-day3-4-240301_03012024_155819.csv')
Auto_noheating_10wt_6_day3_5 = pd.read_csv('Data/compression 6/AutoNoheating-10-6-day3-5-240301_03012024_160114.csv')

data_list_10_6_day3 = [Auto_noheating_10wt_6_day3_1, Auto_noheating_10wt_6_day3_2, Auto_noheating_10wt_6_day3_3, Auto_noheating_10wt_6_day3_4, Auto_noheating_10wt_6_day3_5]
thickness_10_6_day3 = [74, 76, 121, 119, 113]

Auto_heating_12_7_1_1 = pd.read_csv('Data/compression 7/AutoHeating-12-7-1-1-240320_03202024_202947.csv')
Auto_heating_12_7_1_2 = pd.read_csv('Data/compression 7/AutoHeating-12-7-1-2-240320_03202024_203323.csv')
Auto_heating_12_7_1_3 = pd.read_csv('Data/compression 7/AutoHeating-12-7-1-3-240320_03202024_203606.csv')
Auto_heating_12_7_1_4 = pd.read_csv('Data/compression 7/AutoHeating-12-7-1-4-240320_03202024_203910.csv')

data_list_12_7_1 = [Auto_heating_12_7_1_1, Auto_heating_12_7_1_2, Auto_heating_12_7_1_3, Auto_heating_12_7_1_4]
thickness_12_7_1 = [115, 122, 125, 125]

Auto_heating_12_7_2_1 = pd.read_csv('Data/compression 7/AutoHeating-12-7-2-1-240320_03202024_204415.csv')
Auto_heating_12_7_2_2 = pd.read_csv('Data/compression 7/AutoHeating-12-7-2-2-240320_03202024_204706.csv')
Auto_heating_12_7_2_3 = pd.read_csv('Data/compression 7/AutoHeating-12-7-2-3-240320_03202024_204950.csv')
Auto_heating_12_7_2_4 = pd.read_csv('Data/compression 7/AutoHeating-12-7-2-4-240320_03202024_205221.csv')

data_list_12_7_2 = [Auto_heating_12_7_2_1, Auto_heating_12_7_2_2, Auto_heating_12_7_2_3, Auto_heating_12_7_2_4]
thickness_12_7_2 = [108,112,116,115]

Auto_heating_12_8_1 = pd.read_csv('Data/compression 8/AutoHeating-12-8-1-1-240328_03282024_152144.csv')
Auto_heating_12_8_2 = pd.read_csv('Data/compression 8/AutoHeating-12-8-1-2-240328_03282024_152416.csv')
Auto_heating_12_8_3 = pd.read_csv('Data/compression 8/AutoHeating-12-8-1-3-240328_03282024_152657.csv')
Auto_heating_12_8_4 = pd.read_csv('Data/compression 8/AutoHeating-12-8-1-4-240328_03282024_152944.csv')
thickness_12_8 = [100,105,110,116]

data_list_12_8 = [Auto_heating_12_8_1, Auto_heating_12_8_2, Auto_heating_12_8_3, Auto_heating_12_8_4]

Auto_heating_17_8_1 = pd.read_csv('Data/compression 8/AutoHeating-17-8-1-1-240328_03282024_153404.csv')
Auto_heating_17_8_2 = pd.read_csv('Data/compression 8/AutoHeating-17-8-1-2-240328_03282024_153634.csv')
Auto_heating_17_8_3 = pd.read_csv('Data/compression 8/AutoHeating-17-8-1-3-240328_03282024_153853.csv')
Auto_heating_17_8_4 = pd.read_csv('Data/compression 8/AutoHeating-17-8-1-4-240328_03282024_154142.csv')
thickness_17_8 = [103,104,107,109]

data_list_17_8 = [Auto_heating_17_8_1, Auto_heating_17_8_2, Auto_heating_17_8_3, Auto_heating_17_8_4]

Auto_heating_13_9_1 = pd.read_csv('Data/compression 9/AutoHeating-13-9-1--240404_04042024_173756.csv')
Auto_heating_13_9_2 = pd.read_csv('Data/compression 9/AutoHeating-13-9-2--240404_04042024_174116.csv')
Auto_heating_13_9_3 = pd.read_csv('Data/compression 9/AutoHeating-13-9-3--240404_04042024_174359.csv')  
Auto_heating_13_9_4 = pd.read_csv('Data/compression 9/AutoHeating-13-9-4--240404_04042024_174655.csv')
thickness_13_9 = [112,121,125,137]

data_list_13_9 = [Auto_heating_13_9_1, Auto_heating_13_9_2, Auto_heating_13_9_3, Auto_heating_13_9_4]

# %%
def load_plot_data(data_list, thickness_info = True, thickness_list = None, cut_off_load = 2, n_breakpoints=5):
    # convert in to um
    for i in range(len(data_list)):
        data_list[i]['S:LVDT (um)'] = data_list[i]['S:LVDT (in)'] * 25.4 * 1000
        # create stress column which is load / area, the area is 19.635 mm^2
        data_list[i]['stress (bar)'] = data_list[i]['Ch:Load (N)'] / 19.635 *10

    if thickness_info:
        thickness = thickness_list
        x_axis = 'strain'
        x_axis_label = 'Strain'
        # convert in to um
        for i in range(len(data_list)): 
            # create strain column which is displacement / thickness, the thickness is shown above
            data_list[i]['strain'] = data_list[i]['S:LVDT (um)'] / thickness[i]
    else:
        x_axis = 'S:LVDT (um)'
        x_axis_label = 'Displacement (um)'
    data_list_cleaned = []
    # Plot these in the same graph to compare them
    plt.figure(figsize=(8, 6))
    for i in range(len(data_list)):
        data_name = namestr(data_list[i], globals())
        data = data_list[i][data_list[i]['Ch:Load (N)'] > cut_off_load]
        data = data.loc[:data['Ch:Load (N)'].idxmax()]
        # shift the data so that the first point is at 0 in 'S:LVDT (in)'
        data[x_axis] = data[x_axis] - data[x_axis].iloc[0]
        data_list_cleaned.append(data)
        plt.plot(data[x_axis], data['stress (bar)'], label=data_name)
    plt.xlabel(x_axis_label)
    plt.ylabel('Stress (bar)')
    plt.legend(loc='upper left')
    plt.show()
    # concatenate all the data into one dataframe
    data_all = pd.concat(data_list_cleaned, ignore_index=True)
    # sort the values by strain
    data_all = data_all.sort_values(by=x_axis)

    # fit the data with piecewise regression
    pw_fit = piecewise_regression.Fit(list(data_all[x_axis]), list(data_all['stress (bar)']), n_breakpoints=n_breakpoints)
    pw_fit.plot_fit(color="red", linewidth=2)
    pw_fit.plot_data(color="grey", s=1)
    pw_fit.plot_breakpoints()
    pw_fit.plot_breakpoint_confidence_intervals()
    plt.title("Piecewise Regression")
    plt.xlabel(x_axis_label)
    plt.ylabel("Stress (bar)")
    plt.show()
    pw_fit.summary()
    return pw_fit

# %%
fit_10_1 = load_plot_data(data_list_10_1, thickness_info = False)
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    28391
# No. Model Parameters                   12
# Degrees of Freedom                  28379
# Res. Sum of Squares           7.67823e+06
# Total Sum of Squares          3.16488e+07
# R Squared                        0.757393
# Adjusted R Squared               0.757290
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const               -2.82172        0.286      -9.8698      6.13e-23      -3.3821      -2.2614
# alpha1              0.280701       0.0064       43.871           0.0      0.26816      0.29324
# beta1                1.75191        0.025        70.17             -        1.703       1.8008
# beta2               -26.9051         1.83      -14.705             -      -30.491      -23.319
# ...

# %%
fit_12_1_1 = load_plot_data(data_list_12_1_1, thickness_info = False)
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    26576
# No. Model Parameters                   12
# Degrees of Freedom                  26564
# Res. Sum of Squares           4.40596e+06
# Total Sum of Squares          2.90716e+07
# R Squared                        0.848445
# Adjusted R Squared               0.848376
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const               0.269982        0.604       0.4472         0.655     -0.91334       1.4533
# alpha1              0.290266       0.0727       3.9943      6.51e-05      0.14783      0.43271
# beta1                0.32859        0.073       4.5037             -      0.18558       0.4716
# beta2                4.84476       0.0683       70.929             -       4.7109       4.9786
# ...

# %%
fit_12_1_2 = load_plot_data(data_list_12_1_2, thickness_info = False)
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    27169
# No. Model Parameters                   12
# Degrees of Freedom                  27157
# Res. Sum of Squares           4.35136e+06
# Total Sum of Squares          2.77214e+07
# R Squared                        0.843032
# Adjusted R Squared               0.842963
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const               0.774724        0.967      0.80076         0.423      -1.1216        2.671
# alpha1              0.316802        0.269        1.179         0.238     -0.20988      0.84349
# beta1               0.406266        0.269       1.5102             -     -0.12101      0.93354
# beta2              -0.364013       0.0181      -20.091             -     -0.39953      -0.3285
# ...

# %%
fit_15_1 = load_plot_data(data_list_15_1, thickness_info = False)
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    26666
# No. Model Parameters                   12
# Degrees of Freedom                  26654
# Res. Sum of Squares           2.15807e+06
# Total Sum of Squares          4.15988e+07
# R Squared                        0.948122
# Adjusted R Squared               0.948099
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const               -1.11393        0.302       -3.686      0.000228      -1.7063     -0.52158
# alpha1              0.820053       0.0315       26.027     1.72e-147       0.7583      0.88181
# beta1               0.761157       0.0351       21.696             -      0.69239      0.82992
# beta2              -0.440586       0.0177      -24.839             -     -0.47535     -0.40582
# ...

# %%
fit_10_1_H = load_plot_data(data_list_10_1_H, thickness_info = False)
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    28276
# No. Model Parameters                   12
# Degrees of Freedom                  28264
# Res. Sum of Squares           7.25001e+06
# Total Sum of Squares           3.1044e+07
# R Squared                        0.766460
# Adjusted R Squared               0.766361
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const                0.57912        0.673      0.86088         0.389     -0.73942       1.8977
# alpha1              0.235729       0.0731       3.2255       0.00126     0.092482      0.37898
# beta1             -0.0849598        0.177     -0.48036             -     -0.43162       0.2617
# beta2             -0.0727082        0.161     -0.45059             -     -0.38899      0.24357
# ...

# %%
fit_12_1_H = load_plot_data(data_list_12_1_H, thickness_info = False)
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    27519
# No. Model Parameters                   12
# Degrees of Freedom                  27507
# Res. Sum of Squares           4.21258e+06
# Total Sum of Squares          2.81923e+07
# R Squared                        0.850577
# Adjusted R Squared               0.850511
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const               0.387172          0.5      0.77409         0.439     -0.59318       1.3675
# alpha1              0.361862       0.0642       5.6346      1.77e-08      0.23598      0.48774
# beta1               0.169951       0.0757       2.2458             -     0.021623      0.31828
# beta2              -0.317306       0.0423      -7.4935             -      -0.4003     -0.23431
# ...

# %%
fit_15_1_H = load_plot_data(data_list_15_1_H, thickness_info = False)
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    26269
# No. Model Parameters                   12
# Degrees of Freedom                  26257
# Res. Sum of Squares           5.04251e+06
# Total Sum of Squares          3.54947e+07
# R Squared                        0.857936
# Adjusted R Squared               0.857871
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const              -0.228473        0.464     -0.49227         0.623      -1.1382      0.68123
# alpha1              0.504614        0.045       11.223      3.65e-29      0.41649      0.59274
# beta1               0.409659       0.0468       8.7503             -       0.3179      0.50142
# beta2               0.316686        0.056       5.6572             -      0.20696      0.42641
# ...

# %%
fit_17_1_H = load_plot_data(data_list_17_1_H, thickness_info = False)
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    23670
# No. Model Parameters                   12
# Degrees of Freedom                  23658
# Res. Sum of Squares            1.0796e+06
# Total Sum of Squares          3.36874e+07
# R Squared                        0.967952
# Adjusted R Squared               0.967936
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const               0.458067        0.433        1.057          0.29     -0.39132       1.3075
# alpha1              0.332163       0.0905       3.6694      0.000244      0.15473      0.50959
# beta1               0.412271        0.157       2.6294             -      0.10495       0.7196
# beta2               0.361786        0.128       2.8247             -      0.11074      0.61283
# ...

# %%
fit_10_2 = load_plot_data(data_list_10_2, thickness_info = False)
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    28311
# No. Model Parameters                   12
# Degrees of Freedom                  28299
# Res. Sum of Squares           6.43887e+06
# Total Sum of Squares          3.35219e+07
# R Squared                        0.807921
# Adjusted R Squared               0.807839
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const                1.00354        0.436       2.3006        0.0214      0.14854       1.8585
# alpha1              0.360211       0.0399       9.0184      2.03e-19      0.28192       0.4385
# beta1              -0.236277       0.0419      -5.6446             -     -0.31832     -0.15423
# beta2               0.179249       0.0617       2.9041             -     0.058268      0.30023
# ...

# %%
fit_12_2 = load_plot_data(data_list_12_2, thickness_info = False)
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    23824
# No. Model Parameters                   12
# Degrees of Freedom                  23812
# Res. Sum of Squares           5.33838e+06
# Total Sum of Squares          3.39853e+07
# R Squared                        0.842921
# Adjusted R Squared               0.842842
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const               0.976456         0.72       1.3561         0.175     -0.43484       2.3878
# alpha1              0.331536        0.135       2.4555        0.0141     0.066896      0.59618
# beta1              -0.170347        0.137      -1.2478             -     -0.43794     0.097246
# beta2               0.155817       0.0665       2.3441             -     0.025528      0.28611
# ...

# %%
fit_15_2 = load_plot_data(data_list_15_2, thickness_info = False)
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    23395
# No. Model Parameters                   12
# Degrees of Freedom                  23383
# Res. Sum of Squares           5.88527e+05
# Total Sum of Squares          3.24072e+07
# R Squared                        0.981840
# Adjusted R Squared               0.981830
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const               0.551089        0.171       3.2312       0.00123       0.2168      0.88538
# alpha1               1.05769       0.0286       36.962     1.06e-290       1.0016       1.1138
# beta1              -0.549193       0.0292      -18.813             -     -0.60641     -0.49197
# beta2               0.452795       0.0241       18.764             -       0.4055      0.50009
# ...

# %%
fit_10_3 = load_plot_data(data_list_10_3, thickness_info = True, thickness_list = thickness_10_3)
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    23825
# No. Model Parameters                   12
# Degrees of Freedom                  23813
# Res. Sum of Squares           1.24195e+06
# Total Sum of Squares          3.29175e+07
# R Squared                        0.962271
# Adjusted R Squared               0.962252
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const               0.468204        0.272       1.7199        0.0855    -0.065365       1.0018
# alpha1               84.7101         4.95       17.108      3.16e-65       75.005       94.415
# beta1               -41.0381         5.03      -8.1628             -      -50.892      -31.184
# beta2                41.8432          3.4       12.322             -       35.187       48.499
# ...

# %%
fit_12_3 = load_plot_data(data_list_12_3, thickness_info = True, thickness_list = thickness_12_3)
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    23944
# No. Model Parameters                   12
# Degrees of Freedom                  23932
# Res. Sum of Squares               89422.8
# Total Sum of Squares          3.33054e+07
# R Squared                        0.997315
# Adjusted R Squared               0.997314
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const                1.11981       0.0663       16.893      1.18e-63      0.98988       1.2497
# alpha1               99.1625         1.51       65.776           0.0       96.207       102.12
# beta1               -52.5114         1.52      -34.547             -      -55.491      -49.532
# beta2                69.8253        0.742       94.094             -       68.371        71.28
# ...

# %%
fit_15_3 = load_plot_data(data_list_15_3, thickness_info = True, thickness_list = thickness_15_3)
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    21123
# No. Model Parameters                   12
# Degrees of Freedom                  21111
# Res. Sum of Squares           1.34845e+05
# Total Sum of Squares           3.0406e+07
# R Squared                        0.995565
# Adjusted R Squared               0.995563
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const               0.520929       0.0841       6.1919      6.05e-10      0.35603      0.68583
# alpha1               142.988         1.43       100.28           0.0       140.19       145.78
# beta1               -82.4642         1.48      -55.552             -      -85.374      -79.555
# beta2                 57.506         1.19       48.243             -        55.17       59.842
# ...

# %%
fit_17_3 = load_plot_data(data_list_17_3, thickness_info = True, thickness_list = thickness_17_3)
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    20524
# No. Model Parameters                   12
# Degrees of Freedom                  20512
# Res. Sum of Squares           1.20986e+05
# Total Sum of Squares          2.89242e+07
# R Squared                        0.995817
# Adjusted R Squared               0.995815
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const               0.976869       0.0734       13.301      3.36e-40      0.83291       1.1208
# alpha1               192.743         1.32       145.95           0.0       190.15       195.33
# beta1               -117.419          1.4      -83.891             -      -120.16      -114.68
# beta2                47.3298          1.3       36.273             -       44.772       49.887
# ...

# %%
fit_10_4 = load_plot_data(data_list_10_4, thickness_info = True, thickness_list = thickness_10_4)
# Out:
# Algorithm didn't converge. No fit to plot.
# Algorithm didn't converge. No breakpoints to plot
# Algorithm didn't converge. No breakpoint estimates to plot
# Algorithm did not converge. Try different n_breakpoints, different start_values, or start_values=None
# Summary of why the algorithm did not converge:
# Run 1: Breakpoint values too close together
# Run 2: Breakpoint values outside range
# Run 3: Breakpoint values too close together
# Run 4: Breakpoint values outside range
# Run 5: Algorithm stopped as max iterations reached
# Run 6: Breakpoint values outside range
# Run 7: Breakpoint values outside range
# Run 8: Breakpoint values outside range
# Run 9: Breakpoint values outside range
# Run 10: Breakpoint values outside range
# Run 11: Breakpoint values too close together
# Run 12: Breakpoint values outside range
# Run 13: Breakpoint values outside range
# Run 14: Breakpoint values too close together
# Run 15: Breakpoint values too close together
# ...

# %%
fit_12_4 = load_plot_data(data_list_12_4, thickness_info = True, thickness_list = thickness_12_4)
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    33094
# No. Model Parameters                   12
# Degrees of Freedom                  33082
# Res. Sum of Squares           1.24093e+07
# Total Sum of Squares          4.19583e+07
# R Squared                        0.704247
# Adjusted R Squared               0.704140
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const               0.782479        0.586       1.3364         0.181     -0.36515       1.9301
# alpha1               34.8934         6.88       5.0742      3.91e-07       21.415       48.372
# beta1               -3.21063         19.1     -0.16806             -      -40.656       34.235
# beta2               -9.72587         18.2      -0.5357             -      -45.311       25.859
# ...

# %%
fit_15_4 = load_plot_data(data_list_15_4, thickness_info = True, thickness_list = thickness_15_4)
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    21757
# No. Model Parameters                   12
# Degrees of Freedom                  21745
# Res. Sum of Squares           4.64567e+05
# Total Sum of Squares          3.17964e+07
# R Squared                        0.985389
# Adjusted R Squared               0.985381
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const               0.321351         0.17       1.8932        0.0583    -0.011349      0.65405
# alpha1               119.287         3.27       36.465     1.26e-282       112.88        125.7
# beta1               -67.6678         3.34      -20.233             -      -74.223      -61.113
# beta2                58.1922         2.03       28.614             -       54.206       62.178
# ...

# %%
fit_17_4 = load_plot_data(data_list_17_4, thickness_info = True, thickness_list = thickness_17_4)
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    21135
# No. Model Parameters                   12
# Degrees of Freedom                  21123
# Res. Sum of Squares               79516.3
# Total Sum of Squares          2.98407e+07
# R Squared                        0.997335
# Adjusted R Squared               0.997334
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const              -0.104899       0.0655      -1.6006         0.109     -0.23336      0.02356
# alpha1               175.511         1.18        149.0           0.0        173.2       177.82
# beta1               -101.955         1.21       -84.42             -      -104.32      -99.588
# beta2                79.8179        0.916       87.178             -       78.023       81.613
# ...

# %%
fit_10_5 = load_plot_data(data_list_10_5, thickness_info = True, thickness_list = thickness_10_5, n_breakpoints=8)
# Out:
# Algorithm didn't converge. No fit to plot.
# Algorithm didn't converge. No breakpoints to plot
# Algorithm didn't converge. No breakpoint estimates to plot
# Algorithm did not converge. Try different n_breakpoints, different start_values, or start_values=None
# Summary of why the algorithm did not converge:
# Run 1: Breakpoint values outside range
# Run 2: Breakpoint values too close together
# Run 3: Breakpoint values too close together
# Run 4: Breakpoint values outside range
# Run 5: Breakpoint values outside range
# Run 6: Breakpoint values too close together
# Run 7: Breakpoint values outside range
# Run 8: Breakpoint values outside range
# Run 9: Breakpoint values too close together
# Run 10: Breakpoint values outside range
# Run 11: Algorithm stopped as max iterations reached
# Run 12: Breakpoint values outside range
# Run 13: Breakpoint values outside range
# Run 14: Breakpoint values too close together
# Run 15: Breakpoint values outside range
# ...

# %%
fit_17_5 = load_plot_data(data_list_17_5, thickness_info = True, thickness_list = thickness_17_5)
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    20898
# No. Model Parameters                   12
# Degrees of Freedom                  20886
# Res. Sum of Squares           2.47549e+05
# Total Sum of Squares          2.94057e+07
# R Squared                        0.991582
# Adjusted R Squared               0.991577
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const             -0.0632543        0.115     -0.54984         0.582     -0.28874      0.16224
# alpha1               158.108          1.9       83.012           0.0       154.37       161.84
# beta1               -91.4491         1.99      -45.988             -      -95.347      -87.551
# beta2                48.3789         2.08       23.251             -         44.3       52.457
# ...

# %%
fit_10_6_day1 = load_plot_data(data_list_10_6_day1, thickness_info = True, thickness_list = thickness_10_6_day1)
# Out:
# Algorithm didn't converge. No fit to plot.
# Algorithm didn't converge. No breakpoints to plot
# Algorithm didn't converge. No breakpoint estimates to plot
# Algorithm did not converge. Try different n_breakpoints, different start_values, or start_values=None
# Summary of why the algorithm did not converge:
# Run 1: Breakpoint values outside range
# Run 2: Breakpoint values outside range
# Run 3: Breakpoint values too close together
# Run 4: Breakpoint values too close together
# Run 5: Breakpoint values outside range
# Run 6: Breakpoint values outside range
# Run 7: Breakpoint values too close together
# Run 8: Breakpoint values too close together
# Run 9: Breakpoint values too close together
# Run 10: Breakpoint values too close together
# Run 11: Breakpoint values too close together
# Run 12: Breakpoint values too close together
# Run 13: Breakpoint values outside range
# Run 14: Breakpoint values too close together
# Run 15: Breakpoint values outside range
# ...

# %%
fit_10_6_day2 = load_plot_data(data_list_10_6_day2, thickness_info = True, thickness_list = thickness_10_6_day2)
# Out:
# Algorithm didn't converge. No fit to plot.
# Algorithm didn't converge. No breakpoints to plot
# Algorithm didn't converge. No breakpoint estimates to plot
# Algorithm did not converge. Try different n_breakpoints, different start_values, or start_values=None
# Summary of why the algorithm did not converge:
# Run 1: Breakpoint values outside range
# Run 2: Breakpoint values too close together
# Run 3: Breakpoint values outside range
# Run 4: Breakpoint values outside range
# Run 5: Breakpoint values outside range
# Run 6: Breakpoint values outside range
# Run 7: Breakpoint values outside range
# Run 8: Breakpoint values outside range
# Run 9: Breakpoint values outside range
# Run 10: Breakpoint values outside range
# Run 11: Breakpoint values outside range
# Run 12: Breakpoint values outside range
# Run 13: Breakpoint values too close together
# Run 14: Breakpoint values too close together
# Run 15: Breakpoint values outside range
# Run 16: Breakpoint values outside range
# ...

# %%
fit_10_6_day3 = load_plot_data(data_list_10_6_day3, thickness_info = True, thickness_list = thickness_10_6_day3)
# Out:
# Algorithm didn't converge. No fit to plot.
# Algorithm didn't converge. No breakpoints to plot
# Algorithm didn't converge. No breakpoint estimates to plot
# Algorithm did not converge. Try different n_breakpoints, different start_values, or start_values=None
# Summary of why the algorithm did not converge:
# Run 1: Algorithm stopped as max iterations reached
# Run 2: Breakpoint values outside range
# Run 3: Breakpoint values outside range
# Run 4: Breakpoint values outside range
# Run 5: Breakpoint values outside range
# Run 6: Breakpoint values too close together
# Run 7: Breakpoint values outside range
# Run 8: Breakpoint values too close together
# Run 9: Algorithm stopped as max iterations reached
# Run 10: Breakpoint values outside range
# Run 11: Breakpoint values outside range
# Run 12: Algorithm stopped as max iterations reached
# Run 13: Breakpoint values outside range
# Run 14: Algorithm stopped as max iterations reached
# Run 15: Breakpoint values outside range
# ...

# %%
fit_12_7_1 = load_plot_data(data_list_12_7_1, thickness_info = True, thickness_list = thickness_12_7_1, n_breakpoints=5)
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    28314
# No. Model Parameters                   12
# Degrees of Freedom                  28302
# Res. Sum of Squares           5.00338e+06
# Total Sum of Squares          2.89599e+07
# R Squared                        0.827231
# Adjusted R Squared               0.827158
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const               0.396741        0.236       1.6809        0.0928      -0.0659      0.85938
# alpha1               99.2717         1.08       91.538           0.0       97.146        101.4
# beta1               -40.7229         5.26      -7.7368             -       -51.04      -30.406
# beta2                143.117         30.1       4.7532             -         84.1       202.13
# ...

# %%
fit_12_7_2 = load_plot_data(data_list_12_7_2, thickness_info = True, thickness_list = thickness_12_7_2, n_breakpoints=5)
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    26422
# No. Model Parameters                   12
# Degrees of Freedom                  26410
# Res. Sum of Squares             7.148e+06
# Total Sum of Squares          2.85189e+07
# R Squared                        0.749359
# Adjusted R Squared               0.749245
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const               0.805218        0.489       1.6458        0.0998     -0.15376       1.7642
# alpha1               97.5454          6.9       14.134      3.43e-45       84.018       111.07
# beta1               -13.1396          7.1      -1.8512             -      -27.052      0.77244
# beta2                193.774         15.1       12.792             -       164.08       223.46
# ...

# %%
fit_12_8 = load_plot_data(data_list_12_8, thickness_info = True, thickness_list = thickness_12_8, n_breakpoints=5)
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    25983
# No. Model Parameters                   12
# Degrees of Freedom                  25971
# Res. Sum of Squares            8.4984e+06
# Total Sum of Squares          3.01747e+07
# R Squared                        0.718360
# Adjusted R Squared               0.718230
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const               0.427459        0.625      0.68385         0.494     -0.79772       1.6526
# alpha1               72.6406         9.49       7.6515      2.06e-14       54.032       91.249
# beta1               -15.3018         9.57      -1.5985             -      -34.065       3.4609
# beta2                470.856         10.3       45.568             -        450.6       491.11
# ...

# %%
fit_17_8 = load_plot_data(data_list_17_8, thickness_info = True, thickness_list = thickness_17_8, n_breakpoints=5)
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    20994
# No. Model Parameters                   12
# Degrees of Freedom                  20982
# Res. Sum of Squares               35796.9
# Total Sum of Squares          2.95472e+07
# R Squared                        0.998788
# Adjusted R Squared               0.998788
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const               -0.12296       0.0448      -2.7463       0.00603     -0.21072    -0.035203
# alpha1               170.749        0.797       214.36           0.0       169.19       172.31
# beta1               -98.6673        0.815      -121.03             -      -100.27      -97.069
# beta2                79.2991        0.656       120.81             -       78.013       80.586
# ...

# %%
fit_13_9 = load_plot_data(data_list_13_9, thickness_info = True, thickness_list = thickness_13_9, n_breakpoints=5)
# Out:
# Algorithm didn't converge. No fit to plot.
# Algorithm didn't converge. No breakpoints to plot
# Algorithm didn't converge. No breakpoint estimates to plot
# Algorithm did not converge. Try different n_breakpoints, different start_values, or start_values=None
# Summary of why the algorithm did not converge:
# Run 1: Breakpoint values outside range
# Run 2: Breakpoint values outside range
# Run 3: Breakpoint values too close together
# Run 4: Breakpoint values too close together
# Run 5: Breakpoint values outside range
# Run 6: Breakpoint values outside range
# Run 7: Breakpoint values outside range
# Run 8: Breakpoint values too close together
# Run 9: Breakpoint values too close together
# Run 10: Breakpoint values outside range
# Run 11: Breakpoint values outside range
# Run 12: Breakpoint values outside range
# Run 13: Breakpoint values outside range
# Run 14: Algorithm stopped as max iterations reached
# Run 15: Breakpoint values outside range
# ...

# %%
pattern = r'\bR Squared\b\s*(\d+\.\d+)'
r_2 = float(re.findall(pattern,fit_10_2.summary())[0])
r_2
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    28311
# No. Model Parameters                   12
# Degrees of Freedom                  28299
# Res. Sum of Squares           6.43887e+06
# Total Sum of Squares          3.35219e+07
# R Squared                        0.807921
# Adjusted R Squared               0.807839
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const                1.00354        0.436       2.3006        0.0214      0.14854       1.8585
# alpha1              0.360211       0.0399       9.0184      2.03e-19      0.28192       0.4385
# beta1              -0.236277       0.0419      -5.6446             -     -0.31832     -0.15423
# beta2               0.179249       0.0617       2.9041             -     0.058268      0.30023
# ...

# %%
a=float(re.findall(pattern,fit_10_1.summary())[0])
# Out:
#                     Breakpoint Regression Results
# ...
# No. Observations                    28391
# No. Model Parameters                   12
# Degrees of Freedom                  28379
# Res. Sum of Squares           7.67823e+06
# Total Sum of Squares          3.16488e+07
# R Squared                        0.757393
# Adjusted R Squared               0.757290
# Converged:                           True
# ...
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const               -2.82172        0.286      -9.8698      6.13e-23      -3.3821      -2.2614
# alpha1              0.280701       0.0064       43.871           0.0      0.26816      0.29324
# beta1                1.75191        0.025        70.17             -        1.703       1.8008
# beta2               -26.9051         1.83      -14.705             -      -30.491      -23.319
# ...

# %%
pattern = r'\bR Squared\b\s*(\d+\.\d+)'
# save all the fit.get_results() into a dataframe as rows and name them
results = pd.DataFrame()
results = results.append([['10_1', fit_10_1.get_results(), float(re.findall(pattern,fit_10_1.summary())[0])]], ignore_index=True)
results = results.append([['12_1_1', fit_12_1_1.get_results(), float(re.findall(pattern,fit_12_1_1.summary())[0])]], ignore_index=True)
results = results.append([['12_1_2', fit_12_1_2.get_results(), float(re.findall(pattern,fit_12_1_2.summary())[0])]], ignore_index=True)
results = results.append([['15_1', fit_15_1.get_results(), float(re.findall(pattern,fit_15_1.summary())[0])]], ignore_index=True)
results = results.append([['10_1_H', fit_10_1_H.get_results(), float(re.findall(pattern,fit_10_1_H.summary())[0])]], ignore_index=True)
results = results.append([['12_1_H', fit_12_1_H.get_results(), float(re.findall(pattern,fit_12_1_H.summary())[0])]], ignore_index=True)
results = results.append([['15_1_H', fit_15_1_H.get_results(), float(re.findall(pattern,fit_15_1_H.summary())[0])]], ignore_index=True)
results = results.append([['17_1_H', fit_17_1_H.get_results(), float(re.findall(pattern,fit_17_1_H.summary())[0])]], ignore_index=True)
results = results.append([['10_2', fit_10_2.get_results(), float(re.findall(pattern,fit_10_2.summary())[0])]], ignore_index=True)
results = results.append([['12_2', fit_12_2.get_results(), float(re.findall(pattern,fit_12_2.summary())[0])]], ignore_index=True)
results = results.append([['15_2', fit_15_2.get_results(), float(re.findall(pattern,fit_15_2.summary())[0])]], ignore_index=True)
results = results.append([['10_3', fit_10_3.get_results(), float(re.findall(pattern,fit_10_3.summary())[0])]], ignore_index=True)
results = results.append([['12_3', fit_12_3.get_results(), float(re.findall(pattern,fit_12_3.summary())[0])]], ignore_index=True)
results = results.append([['15_3', fit_15_3.get_results(), float(re.findall(pattern,fit_15_3.summary())[0])]], ignore_index=True)
results = results.append([['17_3', fit_17_3.get_results(), float(re.findall(pattern,fit_17_3.summary())[0])]], ignore_index=True)
results = results.append([['10_4', fit_10_4.get_results(), float(re.findall(pattern,fit_10_4.summary())[0])]], ignore_index=True)
results = results.append([['12_4', fit_12_4.get_results(), float(re.findall(pattern,fit_12_4.summary())[0])]], ignore_index=True)
results = results.append([['15_4', fit_15_4.get_results(), float(re.findall(pattern,fit_15_4.summary())[0])]], ignore_index=True)
results = results.append([['17_4', fit_17_4.get_results(), float(re.findall(pattern,fit_17_4.summary())[0])]], ignore_index=True)
results = results.append([['10_5', 'failed', 'failed']], ignore_index=True)
results = results.append([['17_5', fit_17_5.get_results(), float(re.findall(pattern,fit_17_5.summary())[0])]], ignore_index=True)
results = results.append([['10_6_day1', 'failed', 'failed']], ignore_index=True)
results = results.append([['10_6_day2', 'failed', 'failed']], ignore_index=True)
results = results.append([['10_6_day3', fit_10_6_day3.get_results(), float(re.findall(pattern,fit_10_6_day3.summary())[0])]], ignore_index=True)
results = results.append([['12_7_1', fit_12_7_1.get_results(), float(re.findall(pattern,fit_12_7_1.summary())[0])]], ignore_index=True)
results = results.append([['12_7_2', fit_12_7_2.get_results(), float(re.findall(pattern,fit_12_7_2.summary())[0])]], ignore_index=True)
results.columns = ['Sample', 'Results', 'R Squared']
results.to_csv('all_data_fitting.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14916\2735339717.py in ?()
#       1 pattern = r'\bR Squared\b\s*(\d+\.\d+)'
#       2 # save all the fit.get_results() into a dataframe as rows and name them
#       3 results = pd.DataFrame()
# ----> 4 results = results.append([['10_1', fit_10_1.get_results(), float(re.findall(pattern,fit_10_1.summary())[0])]], ignore_index=True)
#       5 results = results.append([['12_1_1', fit_12_1_1.get_results(), float(re.findall(pattern,fit_12_1_1.summary())[0])]], ignore_index=True)
#       6 results = results.append([['12_1_2', fit_12_1_2.get_results(), float(re.findall(pattern,fit_12_1_2.summary())[0])]], ignore_index=True)
#       7 results = results.append([['15_1', fit_15_1.get_results(), float(re.findall(pattern,fit_15_1.summary())[0])]], ignore_index=True)
#
# ...

# %%
results = pd.read_csv('all_data_fitting.csv')
pattern = r'\bR Squared\b\s*(\d+\.\d+)'
results

# %%
# append a new row given the column names and values
results = results.append({'Sample': '12_7_1', 'Results': fit_12_7_1.get_results(), 'R Squared': float(re.findall(pattern,fit_12_7_1.summary())[0])}, ignore_index=True)
results = results.append({'Sample': '12_7_2', 'Results': fit_12_7_2.get_results(), 'R Squared': float(re.findall(pattern,fit_12_7_2.summary())[0])}, ignore_index=True)

# %%
results = results.append({'Sample': '12_8', 'Results': fit_12_8.get_results(), 'R Squared': float(re.findall(pattern,fit_12_8.summary())[0])}, ignore_index=True)
results = results.append({'Sample': '17_8', 'Results': fit_17_8.get_results(), 'R Squared': float(re.findall(pattern,fit_17_8.summary())[0])}, ignore_index=True)
results = results.append({'Sample': '13_9', 'Results': fit_13_9.get_results(), 'R Squared': float(re.findall(pattern,fit_13_9.summary())[0])}, ignore_index=True)

# %%
results

# %%
results.to_csv('all_data_fitting_1.csv', index=False)

# %%
Auto_noheating_17wt_4_1 = pd.read_csv('Data/compression 4 4 days/AutoNoheating-17-4-1-240226_02262024_163853.csv')
Auto_noheating_17wt_4_2 = pd.read_csv('Data/compression 4 4 days/AutoNoheating-17-4-2-240226_02262024_164117.csv')
Auto_noheating_17wt_4_3 = pd.read_csv('Data/compression 4 4 days/AutoNoheating-17-4-3-240226_02262024_164351.csv')
Auto_noheating_17wt_4_4 = pd.read_csv('Data/compression 4 4 days/AutoNoheating-17-4-4-240226_02262024_164621.csv')

data_list = [Auto_noheating_17wt_4_1, Auto_noheating_17wt_4_2, Auto_noheating_17wt_4_3, Auto_noheating_17wt_4_4]
all_data_17 = load_plot_data(data_list, thickness_list= [109,106,106,105])
fit_17 = piecewise_regression_fit(all_data_17, n_breakpoints=5)

# %%
yield_strength_est = fit_17_json['const']['estimate']+fit_17_json['alpha1']['estimate']*fit_17_json['breakpoint1']['estimate']
yield_strength_est

# %%
yield_strength_se = fit_17_json['const']['se']+fit_17_json['alpha1']['se']*fit_17_json['breakpoint1']['se']
yield_strength_se

# %%
elastic_modulus_est = fit_17_json['alpha1']['estimate']
elastic_modulus_est

# %%
fit_17_json

# %%
fit_17.get_results()['rss']

# %%
def extract_properties(fit):
    fit = fit.get_results()
    elastic_modulus_est = fit['alpha1']['estimate']
    elastic_modulus_se = fit['alpha1']['se']
    yield_strength_est = fit['const']['estimate']+fit['alpha1']['estimate']*fit['breakpoint1']['estimate']
    yield_strength_se = fit['const']['se']+fit['alpha1']['se']*fit['breakpoint1']['se']
    rss = fit['rss']
    return elastic_modulus_est, elastic_modulus_se, yield_strength_est, yield_strength_se, rss

# %%
elastic_modulus_se = fit_17_json['alpha1']['se']
elastic_modulus_se

# %%
print(fit_17_json['alpha1']['estimate'], fit_17_json['breakpoint1']['estimate'])

# %%
fit_17.get_results()

# %%
Auto_noheating_15wt_4_1 = pd.read_csv('Data/compression 4 4 days/AutoNoheating-15-4-1-240226_02262024_162514.csv')
Auto_noheating_15wt_4_2 = pd.read_csv('Data/compression 4 4 days/AutoNoheating-15-4-2-240226_02262024_162808.csv')
Auto_noheating_15wt_4_3 = pd.read_csv('Data/compression 4 4 days/AutoNoheating-15-4-3-240226_02262024_163110.csv')
Auto_noheating_15wt_4_4 = pd.read_csv('Data/compression 4 4 days/AutoNoheating-15-4-4-240226_02262024_163353.csv')

data_list = [Auto_noheating_15wt_4_1, Auto_noheating_15wt_4_2, Auto_noheating_15wt_4_3, Auto_noheating_15wt_4_4]
all_data_15 = load_plot_data(data_list, thickness_list= [109,103,100,100])
fit_15 = piecewise_regression_fit(all_data_15, n_breakpoints=5)

# %%
Auto_noheating_10wt_3_1 = pd.read_csv('Data/Compression Sample NH 10, 12, 15, 17 batch 3/AutoNoheating-10-3-1-240212_02122024_160514.csv')
Auto_noheating_10wt_3_2 = pd.read_csv('Data/Compression Sample NH 10, 12, 15, 17 batch 3/AutoNoheating-10-3-2-240212_02122024_160815.csv')
Auto_noheating_10wt_3_3 = pd.read_csv('Data/Compression Sample NH 10, 12, 15, 17 batch 3/AutoNoheating-10-3-3-240212_02122024_161038.csv')
Auto_noheating_10wt_3_4 = pd.read_csv('Data/Compression Sample NH 10, 12, 15, 17 batch 3/AutoNoheating-10-3-4-240212_02122024_161307.csv')

data_list = [Auto_noheating_10wt_3_1, Auto_noheating_10wt_3_2, Auto_noheating_10wt_3_3, Auto_noheating_10wt_3_4]
all_data_10 = load_plot_data(data_list, thickness_list= [109,113,107,106])
fit_10 = piecewise_regression_fit(all_data_10, n_breakpoints=5)
